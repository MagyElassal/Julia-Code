# %%
using Distributions
using PyPlot

# %%
N= rand!(Poisson(1.7),zeros(1,50))
# Out:
# 1x50 Array{Float64,2}:
#  1.0  4.0  1.0  3.0  3.0  1.0  0.0  2.0  …  0.0  3.0  2.0  2.0  2.0  1.0  0.0

# %%
E= rand(Poisson(12.5),200)
# Out:
# 200-element Array{Int64,1}:
#  15
#  18
#  21
#   9
#  13
#  12
#  14
#  12
#  14
#  17
#  12
#  12
#  11
#   ⋮
#   9
#  12
#   8
#   9
#  11
#  12
#  13
#  10
#  20
#  11
#  17
#  20

# %%
plt[:hist](E);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002368FA58>)
