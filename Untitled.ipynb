# %%
leighthouseProb()=(minR = -pi/2;
maxR= pi/2;
r= minR + (rand())/ (maxR- minR))
# Out:
# leighthouseProb (generic function with 1 method)

# %%
N=1;
t= zeros(1,N);
for k=1:N  
    t[k]=leighthouseProb();
end
beta= 1;
alfa= [-5:0.1:5];
x= tan(t) .+ alfa
# Out:
# 101x1 Array{Float64,2}:
#  -19.3774
#  -19.2774
#  -19.1774
#  -19.0774
#  -18.9774
#  -18.8774
#  -18.7774
#  -18.6774
#  -18.5774
#  -18.4774
#  -18.3774
#  -18.2774
#  -18.1774
#    ⋮
#  -10.4774
#  -10.3774
#  -10.2774
#  -10.1774
#  -10.0774
#   -9.97737
#   -9.87737
#   -9.77737
#   -9.67737
#   -9.57737
#   -9.47737
#   -9.37737

# %%
post(::BigData)
post = 1 ./ pi*( 1+ (x .- alfa).^2)
# Out:
# LoadError: syntax: invalid "::" syntax
# while loading In[35], in expression starting on line 2

# %%
minX= 1; maxX= 1000;
x= zeros(1,N);
for k=1:N
    x[k] = minX + (rand()/(maxX - minX))
end
x[1]
# Out:
# 1.0009840899695708

# %%
plot(alfa,post)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000027F83DA0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x00000000282C4CF8>
