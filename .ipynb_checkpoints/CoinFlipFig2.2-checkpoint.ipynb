# %%
using PyPlot;

# %%
coinFlip(w)= (rand()< w)? 1: 0;
function CoinAssignment2(w,num,norm)
    H= [0:0.001:1];
    
    events= zeros(Int,1,num);
    for i=1:num
        events[i]= coinFlip(w);
    end
        
    perior_prob= zeros(3,length(H));
    posterior_prob= zeros(3,length(H));
    norm= zeros(3,2);
    posterior_probNorm= zeros(3,length(H));
    
    #--------------------------------------
    b=1; a=0; #parameters for Uniform distribution
    
    segma= 0.5; meue= 0.5;#parameters for Normal distribution
    
    alfa= 0.5; beta=0.5;#parameters for Beta distribution
    
    N= num; R= sum(events);#parameters for Binomial distribution
    #--------------------------------------------------
    if num > 0
        likelihood= H.^R .* (1-H).^(N-R); #likelihood function follows Binomial Distribution
    else
        likelihood= 1;  #in at first step no data
    end
        
    perior_prob[1,:]= (1/(b-a))*ones(Int,1,length(H)); #perior function follows Uniform distribution
    for i=1:length(H)
        perior_prob[2,i]= (exp(-(H[i]-meue)^2 / (2*segma^2))/(segma*(2* pi)^(1/2)));
        perior_prob[3,i]= (H[i])^(alfa-1)*(1-H[i])^(beta-1);
    end
    #--------------------------------------------------
    posterior_prob= likelihood' .* perior_prob;
    
    if norm > 0
    norm= [minimum(posterior_prob,2) maximum(posterior_prob,2)];
    println(norm)
    
    if (norm[3,2] == Inf)
        k= find(posterior_prob[3,:] == Inf);
        posterior_prob[3,k] = 1;
        norm[3,2]= 1;
        sec_max= maximum(posterior_prob[3,:])
        posterior_prob[3,k] = sec_max + 1;
        norm[3,2]= sec_max+ 1;
    end
    
    for j=1:3
        posterior_probNorm[j,:] = (posterior_prob[j,:] - norm[j,1])./(norm[j,2] - norm[j,1]);
    end 
    end

    
    #posterior_prob= perior_prob; #just for test in the first case (no data)
    
    plot(H,posterior_probNorm');
    #plot(H,posterior_prob');
    ylabel("Posterior Prob")
    xlabel("H wight")
    #return H, posterior_probNorm;
end
# Out:
# CoinAssignment2 (generic function with 2 methods)

# %%
xx= [0:0.001:1]
##length(xx)
#yy= zeros(1,length(xx)-2)
yy= [1 0.8 0.6 0.2 (0.1 .* zeros(1,length(xx)-8)) 0.2 0.6 0.8 1]
plot(xx',yy)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000026812080>)
# 1001-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000029389BE0>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000029389F28>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002938F240>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002938F4A8>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002938F710>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002938F978>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002938FBE0>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000029356550>
#  PyObject <matplotlib.lines.Line2D object at 0x00000000293920F0>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000029392358>
#  PyObject <matplotlib.lines.Line2D object at 0x00000000293925C0>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000029392828>
#  PyObject <matplotlib.lines.Line2D object at 0x0000000029392A90>
#  ⋮
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A89F2B0>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A89F518>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A89F780>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A89F9E8>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A89FC50>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A89ADA0>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A8A2160>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A8A23C8>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A8A2630>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A8A2898>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A8A2B00>
#  PyObject <matplotlib.lines.Line2D object at 0x000000002A8A2D68>

# %%
maximum(po,2)
# Out:
# 2x1 Array{Int64,2}:
#  5
#  6

# %%
CoinAssignment2(0.25,0,0)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# LoadError: UndefVarError: nourm not defined
# while loading In[17], in expression starting on line 1
#
#  in CoinAssignment2 at In[15]:38
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in CoinAssignment2 at In[15]:3
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[17], in expression starting on line 1

# %%
w= 0.25; number=1;
H= [0:0.001:1]
events= zeros(Int,1,number);
    for i=1:number
        events[i]= coinFlip(w);
    end
        
    perior_prob= zeros(3,length(H));
    posterior_prob= zeros(3,length(H));
    norm= zeros(3,2);
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in vect at abstractarray.jl:32
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[4], in expression starting on line 2

# %%
#--------------------------------------
    b=1; a=0; #parameters for Uniform distribution
    
    segma= 0.5; meue= 0.5;#parameters for Normal distribution
    
    alfa= 0.5; beta=0.5;#parameters for Beta distribution
    
N= number; R= sum(events);#parameters for Binomial distribution
    #--------------------------------------------------
# Out:
# 0

# %%
likelihood= H.^R .* (1-H).^(N-R); #likelihood function follows Binomial Distribution
    
    perior_prob[1,:]= (1/(b-a)).*ones(1,length(H)); #perior function follows Uniform distribution
    for i=1:length(H)
        perior_prob[2,i]= (exp(-(H[i]-meue)^2 / (2*segma^2))/(segma*(2* pi)^(1/2)));
        perior_prob[3,i]= (H[i])^(alfa-1)*(1-H[i])^(beta-1);
    end

# %%
for j=1:3
        posterior_prob[j,:]= likelihood .* perior_prob[j,:];
        norm(j,:)= [minimum(posterior_prob[j,:]) maximum(posterior_prob[j,:])];
        
        if (norm[j,2] == Inf)
            k= find(posterior_prob[j,:] .== Inf)
            posterior_prob[j,k] = 1;
            norm[j,2]= 1;
        sec_max= maximum(posterior_prob[j,:])
            posterior_prob[j,k] = sec_max + 1;
            norm[j,2]= sec_max+ 1;
        #end
        #posterior_probNorm[j,:] = (posterior_prob[j,:] - norm[j,1])./(norm[j,2] - norm[j,1]);
    end
# Out:
# LoadError: syntax: incomplete: "for" at In[7]:1 requires end
# while loading In[7], in expression starting on line 1

# %%
CoinAssignment2(0.25,2)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# [
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000028999978>)
# PyObject <matplotlib.text.Text object at 0x000000002BA562E8>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in CoinAssignment2 at In[29]:3
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[49], in expression starting on line 1
# 0.0 0.25
#  0.0 0.19947114020071635
#  0.03160696125855822 0.4999999999999999]

# %%
CoinAssignment2(0.25,4)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# [
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002BA5EE80>)
# PyObject <matplotlib.text.Text object at 0x000000002B5E94E0>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in CoinAssignment2 at In[29]:3
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[50], in expression starting on line 1
# 0.0 0.0625
#  0.0 0.04986778505017909
#  3.157535429729966e-5 0.12499999999999997]

# %%
CoinAssignment2(0.25,5)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# [
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002BA744A8>)
# PyObject <matplotlib.text.Text object at 0x000000002B586550>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in CoinAssignment2 at In[29]:3
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[51], in expression starting on line 1
# 0.0 0.03456000000000001
#  0.0 0.027116679016602665
#  3.1575354297299734e-8 0.07091644310682527]

# %%
CoinAssignment2(0.25,500)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# [
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000018D6BDD8>)
# PyObject <matplotlib.text.Text object at 0x000000002BAF22B0>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in CoinAssignment2 at In[29]:3
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[52], in expression starting on line 1
# 0.0 6.859432995666876e-121
#  0.0 4.790838421857319e-121
#  0.0 1.601643319846033e-120]
