# %%
using PyPlot;
# Out:
# INFO: Loading help data...

# %%
coinFlip(w)= (rand()< w)? 1: 0;
function CoinAssignment1(w,num)
    H= [0:0.001:1];
    
    events= zeros(Int,1,num);
    for i=1:num
        events[i]= coinFlip(w);
    end
    
    N= num; R= sum(events);#parameters for Binomial distribution    
    likelihood= H.^R .* (1-H).^(N-R); #likelihood function follows Binomial Distribution
    
    b=1; a=0; #parameters for Uniform distribution
    perior_prob= 1/(b-a); #perior function follows Uniform distribution
    
    posterior_prob= likelihood .* perior_prob;
    
    norm= [minimum(posterior_prob) maximum(posterior_prob)];
    posterior_probNorm = (posterior_prob - norm[1])./(norm[2] - norm[1]);
    
    println(size(posterior_probNorm))
    plot(H,posterior_probNorm);
    ylabel("Posterior Prob")
    xlabel("H wight")
    
    #return H, posterior_prob;
end
# Out:
# CoinAssignment1 (generic function with 1 method)

# %%
CoinAssignment1(0.25,1)
# Out:
# (1001,)
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f1a17318050>)
# PyObject <matplotlib.text.Text object at 0x7f1a34595b90>

# %%
CoinAssignment1(0.25,2)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fadcaf74610>)
# PyObject <matplotlib.text.Text object at 0x7fadcb075350>

# %%
CoinAssignment1(0.25,4)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fadcae1cf90>)
# PyObject <matplotlib.text.Text object at 0x7fadcafc1810>

# %%
CoinAssignment1(0.25,5)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f1a344da450>)
# PyObject <matplotlib.text.Text object at 0x7f1a344ebb10>

# %%
CoinAssignment1(0.25,500)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f1a34595b10>)
# PyObject <matplotlib.text.Text object at 0x7f1a34544310>
