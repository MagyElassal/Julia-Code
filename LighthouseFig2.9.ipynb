# %%
using PyPlot

# %%
function lighthouseProb()
    minR = -pi/2;
    maxR= pi/2;
    r= minR + rand() * (maxR - minR)
end
# Out:
# lighthouseProb (generic function with 1 method)

# %%
function lighthouseExamp(N)
    beta= 1;

    alfa= [-5 : 0.01 : 5];
    R= length(alfa);

   # t= zeros(R,N);

   # for k=1:N, i=1:R  
    #    t[i,k]=lighthouseProb();
    #end
    t= zeros(1,N)
    for k=1:N  
        t[k]=lighthouseProb();
    end

    x = beta .* tan(t) .+ alfa
    L= -sum(log(beta^2 .+ (x .- alfa).^2),2)
    getMaxL= maximum(L);
    modifiedL= L .- getMaxL;
    posterior = exp(modifiedL)
    println(N)
    plot(alfa, posterior)
    
    xlabel("Lighthouse Position alfa (km)")
    ylabel("prob(alfa|{x_k},beta,I)")
    
end
# Out:
# lighthouseExamp (generic function with 1 method)

# %%
lighthouseExamp(1)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# 1
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000037D7B908>)
# PyObject <matplotlib.text.Text object at 0x0000000038171518>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in lighthouseExamp at In[101]:4
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[102], in expression starting on line 1

# %%
lighthouseExamp(2)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# 2
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000381C06D8>)
# PyObject <matplotlib.text.Text object at 0x00000000381D5C18>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in lighthouseExamp at In[101]:4
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[103], in expression starting on line 1

# %%
lighthouseExamp(4)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# 4
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000038342358>)
# PyObject <matplotlib.text.Text object at 0x0000000038245DA0>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in lighthouseExamp at In[101]:4
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[104], in expression starting on line 1

# %%
lighthouseExamp(8)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# 8
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x00000000381C30B8>)
# PyObject <matplotlib.text.Text object at 0x00000000382AB898>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in lighthouseExamp at In[101]:4
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[105], in expression starting on line 1

# %%
lighthouseExamp(64)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# 64
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000037D825F8>)
# PyObject <matplotlib.text.Text object at 0x00000000386D42B0>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in lighthouseExamp at In[101]:4
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[106], in expression starting on line 1

# %%
lighthouseExamp(512)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# 512
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000038F694E0>)
# PyObject <matplotlib.text.Text object at 0x0000000038F81518>
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in lighthouseExamp at In[101]:4
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[109], in expression starting on line 1
