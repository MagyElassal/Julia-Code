# %%
using PyPlot
# Out:
# INFO: Precompiling module Images...
# WARNING: requiring "LaTex" in module "Main" did not define a corresponding module.

# %%
function LighthouseProb(N) #input number of flashes "N"                  
    #----------- Data generation------------------------
    α = 1                       # position of the lighthouse
    β= 1       
    θ = rand(-π/2:π/2,1,N) 
    
    X= β .* tan(θ) .+ α           #the vector of flashes positions
    #----------------Bayesian Calculations-----------------------------------
    α_range = [-5:0.1:5]
    L= -sum(log(β^2 .+ (X .- α_range).^2),2)
    getMaxL= maximum(L);
    modifiedL= L .- getMaxL;
    posterior = exp(modifiedL)
    μ = mean(posterior)
    
    #--------Ploting Postrior---------------------------- 
    plot(α_range, posterior)
    xlabel("Lighthouse Position α (km)")
    ylabel("prob(α|{X},β,I)")
    
    println("Mean Value: ",μ)
    
end
# Out:
# LighthouseProb (generic function with 1 method)

# %%
LighthouseProb(1)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# Mean Value:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002CAA8A58>)
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in LighthouseProb at In[79]:10
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[80], in expression starting on line 1
# 0.24864322216266194

# %%
LighthouseProb(2)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# Mean Value:
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in LighthouseProb at In[79]:10
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[81], in expression starting on line 1
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030330278>)
# 0.2726379544396532

# %%
LighthouseProb(4)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# Mean Value:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x0000000030355860>)
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in LighthouseProb at In[79]:10
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[82], in expression starting on line 1
# 0.14720696649768064

# %%
LighthouseProb(8)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# Mean Value:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002F389400>)
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in LighthouseProb at In[79]:10
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[83], in expression starting on line 1
# 0.1441018526246988

# %%
LighthouseProb(64)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# Mean Value:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000003042FE48>)
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in LighthouseProb at In[79]:10
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[84], in expression starting on line 1
# 0.048567106535770836

# %%
LighthouseProb(512)
# Out:
# WARNING: [a] concatenation is deprecated; use collect(a) instead
# Mean Value:
#  in depwarn at deprecated.jl:73
#  in oldstyle_vcat_warning at abstractarray.jl:29
#  in LighthouseProb at In[79]:10
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at C:\Users\Magy\.julia\v0.4\IJulia\src\execute_request.jl:177
#  in eventloop at C:\Users\Magy\.julia\v0.4\IJulia\src\IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[85], in expression starting on line 1
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000002F49FBE0>)
# 0.021473296828975707
